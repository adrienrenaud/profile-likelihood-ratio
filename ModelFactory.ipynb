# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import minimize as sp_minimize
# %matplotlib inline

# %%
from Likelihood import Model, ModelFactory
from Likelihood import Profile_likelihood_ratio_result

# %%
model_fatory = ModelFactory(n_exp=10000, n_data=10000, debug_level=0)
df = model_fatory.run()
# Out:
# ::: output_file   : mod_fact_out_ndata_10000_nexp_10000
# ::: output_tag    : foo
# ::: true_mu       : 0.0
# ::: n_data        : 10000
# ::: debug_level   : 0
# ::: function_type : m2_log_likelihood_gaus
# ::: true_sigma    : 1.0
# ::: n_exp         : 10000
# ::: Iteration 0 (10000 to go)
# ::: Iteration 100 (9900 to go)
# ::: Iteration 200 (9800 to go)
# ::: Iteration 300 (9700 to go)
# ::: Minimization Failed in finding Confidence Interval!!!!!!
#      fun: 2207110453214.0322
#      jac: array([  1.08105990e+11,  -6.46987170e+16,   0.00000000e+00])
#  message: 'Inequality constraints incompatible'
#     nfev: 119
#      nit: 16
#     njev: 16
#   status: 4
#  success: False
#        x: array([  2.54520954e-02,   6.82049854e-05])
# ::: Iteration 400 (9600 to go)
# ::: Minimization Failed in finding Confidence Interval!!!!!!
#      fun: 7734838342.4075069
#      jac: array([  3.07278912e+08,  -1.35074067e+13,   0.00000000e+00])
#  message: 'Inequality constraints incompatible'
#     nfev: 119
#      nit: 16
#     njev: 16
#   status: 4
#  success: False
#        x: array([ 0.01657163,  0.00114527])
# ::: Iteration 500 (9500 to go)
# ::: Iteration 600 (9400 to go)
# ::: Iteration 700 (9300 to go)
# ::: Minimization Failed in finding Confidence Interval!!!!!!
#      fun: 2238459214.2167792
#      jac: array([ -8.95004800e+07,  -2.11717134e+12,   0.00000000e+00])
#  message: 'Inequality constraints incompatible'
#     nfev: 107
#      nit: 13
#     njev: 13
#   status: 4
#  success: False
#        x: array([-0.00855397,  0.00211464])
# ::: Iteration 800 (9200 to go)
# ::: Minimization Failed in finding Confidence Interval!!!!!!
#      fun: 166398015817.41324
#      jac: array([  3.38775654e+09,  -1.35321300e+15,   0.00000000e+00])
#  message: 'Inequality constraints incompatible'
#     nfev: 101
#      nit: 13
#     njev: 13
#   status: 4
#  success: False
#        x: array([ 0.0193371 ,  0.00024591])
# ::: Iteration 900 (9100 to go)
# ::: Minimization Failed in finding Confidence Interval!!!!!!
#      fun: 8921461222.0041561
#      jac: array([ -2.46633472e+08,  -1.67917827e+13,   0.00000000e+00])
#  message: 'Inequality constraints incompatible'
#     nfev: 107
#      nit: 13
#     njev: 13
#   status: 4
#  success: False
#        x: array([-0.00058915,  0.00106259])
# ::: Iteration 1000 (9000 to go)
# ::: Minimization Failed in finding Confidence Interval!!!!!!
#      fun: 14891798662.846558
#      jac: array([  3.10816512e+08,  -3.68040352e+13,   0.00000000e+00])
#  message: 'Inequality constraints incompatible'
#     nfev: 107
#      nit: 13
#     njev: 13
#   status: 4
#  success: False
#        x: array([ 0.01168829,  0.00080923])
# ::: Iteration 1100 (8900 to go)
# ::: Minimization Failed in finding Confidence Interval!!!!!!
#      fun: 1881728525.4414718
#      jac: array([ -3.72068000e+07,   1.61405586e+12,   0.00000000e+00])
#  message: 'Inequality constraints incompatible'
#     nfev: 128
#      nit: 15
#     njev: 15
#   status: 4
#  success: False
#        x: array([-0.02872663, -0.00233181])
# ::: Iteration 1200 (8800 to go)
# ::: Iteration 1300 (8700 to go)
# ::: Iteration 1400 (8600 to go)
# ::: Iteration 1500 (8500 to go)
# ::: Iteration 1600 (8400 to go)
# ::: Iteration 1700 (8300 to go)
# ::: Iteration 1800 (8200 to go)
# ::: Minimization Failed in finding Confidence Interval!!!!!!
#      fun: 19094931265318.988
#      jac: array([  3.86930311e+11,  -1.66783400e+18,   0.00000000e+00])
#  message: 'Inequality constraints incompatible'
#     nfev: 119
#      nit: 16
#     njev: 16
#   status: 4
#  success: False
#        x: array([  1.90582607e-03,   2.28755259e-05])
# ::: Minimization Failed in finding Confidence Interval!!!!!!
#      fun: 799055001.81304967
#      jac: array([  3.21863360e+07,  -4.56468504e+11,   0.00000000e+00])
#  message: 'Inequality constraints incompatible'
#     nfev: 119
#      nit: 16
#     njev: 16
#   status: 4
#  success: False
#        x: array([ 0.00458179,  0.00350138])
# ::: Minimization Failed in finding Confidence Interval!!!!!!
#      fun: 25592908279.633049
#      jac: array([ -5.17378048e+08,   8.27757378e+13,   0.00000000e+00])
#  message: 'Inequality constraints incompatible'
#     nfev: 86
#      nit: 11
#     njev: 11
#   status: 4
#  success: False
#        x: array([-0.02066893, -0.00061839])
# ::: Iteration 1900 (8100 to go)
# ::: Iteration 2000 (8000 to go)
# ::: Minimization Failed in finding Confidence Interval!!!!!!
#      fun: 859845029.31367731
#      jac: array([  3.48058000e+07,  -5.07801977e+11,   0.00000000e+00])
#  message: 'Inequality constraints incompatible'
#     nfev: 108
#      nit: 13
#     njev: 13
#   status: 4
#  success: False
#        x: array([ 0.02461427,  0.00338685])
# ::: Iteration 2100 (7900 to go)
# ::: Iteration 2200 (7800 to go)
# ::: Iteration 2300 (7700 to go)
# ::: Iteration 2400 (7600 to go)
# ::: Iteration 2500 (7500 to go)
# ::: Minimization Failed in finding Confidence Interval!!!!!!
#      fun: 1742126770.5495162
#      jac: array([  7.02381600e+07,  -1.46465105e+12,   0.00000000e+00])
#  message: 'Inequality constraints incompatible'
#     nfev: 100
#      nit: 13
#     njev: 13
#   status: 4
#  success: False
#        x: array([ 0.0215306,  0.002379 ])
# ::: Iteration 2600 (7400 to go)
# ::: Iteration 2700 (7300 to go)
# ::: Minimization Failed in finding Confidence Interval!!!!!!
#      fun: 9330167537.4631748
#      jac: array([  3.91265536e+08,  -1.79641060e+13,   0.00000000e+00])
#  message: 'Inequality constraints incompatible'
#     nfev: 105
#      nit: 13
#     njev: 13
#   status: 4
#  success: False
#        x: array([ 0.03216565,  0.00103875])
# ::: Iteration 2800 (7200 to go)
# ::: Iteration 2900 (7100 to go)
# ::: Minimization Failed in finding Confidence Interval!!!!!!
#      fun: 1120250028.962527
#      jac: array([  2.24528320e+07,  -7.44869172e+11,   0.00000000e+00])
#  message: 'Inequality constraints incompatible'
#     nfev: 106
#      nit: 13
#     njev: 13
#   status: 4
#  success: False
#        x: array([ 0.02450106,  0.00300812])
# ::: Iteration 3000 (7000 to go)
# ::: Minimization Failed in finding Confidence Interval!!!!!!
#      fun: 212122909880.28006
#      jac: array([  8.56708710e+09,  -1.94478553e+15,   0.00000000e+00])
#  message: 'Inequality constraints incompatible'
#     nfev: 119
#      nit: 16
#     njev: 16
#   status: 4
#  success: False
#        x: array([ 0.01499881,  0.00021812])
# ::: Iteration 3100 (6900 to go)
# ::: Iteration 3200 (6800 to go)
# ::: Minimization Failed in finding Confidence Interval!!!!!!
#      fun: 86167861201.227142
#      jac: array([  3.17283226e+09,  -5.05735294e+14,   0.00000000e+00])
#  message: 'Inequality constraints incompatible'
#     nfev: 107
#      nit: 13
#     njev: 13
#   status: 4
#  success: False
#        x: array([ 0.02787334,  0.00034074])
# ::: Iteration 3300 (6700 to go)
# ::: Iteration 3400 (6600 to go)
# ::: Minimization Failed in finding Confidence Interval!!!!!!
#      fun: 2588843368863.9126
#      jac: array([ -1.03771374e+11,  -8.24728155e+16,   0.00000000e+00])
#  message: 'Inequality constraints incompatible'
#     nfev: 110
#      nit: 14
#     njev: 14
#   status: 4
#  success: False
#        x: array([ -4.44247547e-03,   6.27581774e-05])
# ::: Iteration 3500 (6500 to go)
# ::: Iteration 3600 (6400 to go)
# ::: Iteration 3700 (6300 to go)
# ::: Iteration 3800 (6200 to go)
# ::: Minimization Failed in finding Confidence Interval!!!!!!
#      fun: 5672579386.3525524
#      jac: array([ -2.29725952e+08,  -8.49776485e+12,   0.00000000e+00])
#  message: 'Inequality constraints incompatible'
#     nfev: 107
#      nit: 13
#     njev: 13
#   status: 4
#  success: False
#        x: array([-0.00566261,  0.00133508])
# ::: Iteration 3900 (6100 to go)
# ::: Iteration 4000 (6000 to go)
# ::: Iteration 4100 (5900 to go)
# ::: Iteration 4200 (5800 to go)
# ::: Minimization Failed in finding Confidence Interval!!!!!!
#      fun: 148903301243.18518
#      jac: array([  5.92668672e+09,  -1.14236032e+15,   0.00000000e+00])
#  message: 'Inequality constraints incompatible'
#     nfev: 125
#      nit: 16
#     njev: 16
#   status: 4
#  success: False
#        x: array([ 0.01332964,  0.00026067])
# ::: Iteration 4300 (5700 to go)
# ::: Iteration 4400 (5600 to go)
# ::: Minimization Failed in finding Confidence Interval!!!!!!
#      fun: 696311770.19230127
#      jac: array([  2.81841360e+07,  -3.66139206e+11,   0.00000000e+00])
#  message: 'Inequality constraints incompatible'
#     nfev: 107
#      nit: 13
#     njev: 13
#   status: 4
#  success: False
#        x: array([ 0.03219472,  0.00380397])
# ::: Iteration 4500 (5500 to go)
# ::: Iteration 4600 (5400 to go)
# ::: Minimization Failed in finding Confidence Interval!!!!!!
#      fun: 2368344016.2051568
#      jac: array([ -8.56687040e+07,  -2.29910853e+12,   0.00000000e+00])
#  message: 'Inequality constraints incompatible'
#     nfev: 108
#      nit: 13
#     njev: 13
#   status: 4
#  success: False
#        x: array([-0.00531904,  0.00206029])
# ::: Minimization Failed in finding Confidence Interval!!!!!!
#      fun: 3920827365.7833381
#      jac: array([  7.87432960e+07,  -4.93073173e+12,   0.00000000e+00])
#  message: 'Inequality constraints incompatible'
#     nfev: 101
#      nit: 13
#     njev: 13
#   status: 4
#  success: False
#        x: array([ 0.01419456,  0.00159038])
# ::: Iteration 4700 (5300 to go)
# ::: Minimization Failed in finding Confidence Interval!!!!!!
#      fun: 61831140190.100746
#      jac: array([  6.36407808e+08,  -3.10043363e+14,   0.00000000e+00])
#  message: 'Inequality constraints incompatible'
#     nfev: 107
#      nit: 13
#     njev: 13
#   status: 4
#  success: False
#        x: array([ 0.00962589,  0.00039883])
# ::: Iteration 4800 (5200 to go)
# ::: Minimization Failed in finding Confidence Interval!!!!!!
#      fun: 35268974005.912659
#      jac: array([ -7.06800640e+08,   1.32746517e+14,   0.00000000e+00])
#  message: 'Inequality constraints incompatible'
#     nfev: 118
#      nit: 15
#     njev: 15
#   status: 4
#  success: False
#        x: array([-0.00301416, -0.0005314 ])
# ::: Iteration 4900 (5100 to go)
# ::: Iteration 5000 (5000 to go)
# ::: Minimization Failed in finding Confidence Interval!!!!!!
#      fun: 1748193967232729.2
#      jac: array([ -3.54879390e+13,  -1.45965957e+21,   0.00000000e+00])
#  message: 'Inequality constraints incompatible'
#     nfev: 101
#      nit: 13
#     njev: 13
#   status: 4
#  success: False
#        x: array([ -7.18860901e-03,   2.37296971e-06])
# ::: Iteration 5100 (4900 to go)
# ::: Iteration 5200 (4800 to go)
# ::: Minimization Failed in finding Confidence Interval!!!!!!
#      fun: 1812522316.4999471
#      jac: array([  3.63233280e+07,  -1.54540176e+12,   0.00000000e+00])
#  message: 'Inequality constraints incompatible'
#     nfev: 107
#      nit: 13
#     njev: 13
#   status: 4
#  success: False
#        x: array([ 0.01892056,  0.00234579])
# ::: Iteration 5300 (4700 to go)
# ::: Minimization Failed in finding Confidence Interval!!!!!!
#      fun: 60187317164.552628
#      jac: array([  2.42915840e+09,  -2.97836437e+14,   0.00000000e+00])
#  message: 'Inequality constraints incompatible'
#     nfev: 107
#      nit: 13
#     njev: 13
#   status: 4
#  success: False
#        x: array([ 0.02333605,  0.00040414])
# ::: Iteration 5400 (4600 to go)
# ::: Minimization Failed in finding Confidence Interval!!!!!!
#      fun: 93640621327.385345
#      jac: array([  3.75310029e+09,  -5.73938366e+14,   0.00000000e+00])
#  message: 'Inequality constraints incompatible'
#     nfev: 107
#      nit: 13
#     njev: 13
#   status: 4
#  success: False
#        x: array([ 0.02814474,  0.00032629])
# ::: Iteration 5500 (4500 to go)
# ::: Iteration 5600 (4400 to go)
# ::: Iteration 5700 (4300 to go)
# ::: Iteration 5800 (4200 to go)
# ::: Minimization Failed in finding Confidence Interval!!!!!!
#      fun: 271341197632.55545
#      jac: array([  5.41326746e+09,   2.82843609e+15,   0.00000000e+00])
#  message: 'Inequality constraints incompatible'
#     nfev: 118
#      nit: 15
#     njev: 15
#   status: 4
#  success: False
#        x: array([ 0.01705047, -0.00019189])
# ::: Iteration 5900 (4100 to go)
# ::: Iteration 6000 (4000 to go)
# ::: Iteration 6100 (3900 to go)
# ::: Iteration 6200 (3800 to go)
# ::: Minimization Failed in finding Confidence Interval!!!!!!
#      fun: 2846987254.4932818
#      jac: array([  1.13655648e+08,  -3.01823445e+12,   0.00000000e+00])
#  message: 'Inequality constraints incompatible'
#     nfev: 107
#      nit: 13
#     njev: 13
#   status: 4
#  success: False
#        x: array([ 0.03396504,  0.00188657])
# ::: Iteration 6300 (3700 to go)
# ::: Minimization Failed in finding Confidence Interval!!!!!!
#      fun: 2199625037.9604897
#      jac: array([  7.34128000e+07,  -2.05780367e+12,   0.00000000e+00])
#  message: 'Inequality constraints incompatible'
#     nfev: 107
#      nit: 13
#     njev: 13
#   status: 4
#  success: False
#        x: array([ 0.02802548,  0.00213791])
# ::: Iteration 6400 (3600 to go)
# ::: Iteration 6500 (3500 to go)
# ::: Minimization Failed in finding Confidence Interval!!!!!!
#      fun: 66012197009.032516
#      jac: array([  1.32559770e+09,  -3.38567214e+14,   0.00000000e+00])
#  message: 'Inequality constraints incompatible'
#     nfev: 119
#      nit: 16
#     njev: 16
#   status: 4
#  success: False
#        x: array([ 0.0033439 ,  0.00038993])
# ::: Iteration 6600 (3400 to go)
# ::: Iteration 6700 (3300 to go)
# ::: Iteration 6800 (3200 to go)
# ::: Iteration 6900 (3100 to go)
# ::: Iteration 7000 (3000 to go)
# ::: Iteration 7100 (2900 to go)
# ::: Iteration 7200 (2800 to go)
# ::: Iteration 7300 (2700 to go)
# ::: Minimization Failed in finding Confidence Interval!!!!!!
#      fun: 9648050089.378891
#      jac: array([ -1.93290240e+08,  -1.89860032e+13,   0.00000000e+00])
#  message: 'Inequality constraints incompatible'
#     nfev: 100
#      nit: 13
#     njev: 13
#   status: 4
#  success: False
#        x: array([-0.00327534,  0.00101632])
# ::: Iteration 7400 (2600 to go)
# ::: Minimization Failed in finding Confidence Interval!!!!!!
#      fun: 6485917374.6699734
#      jac: array([ -1.32150400e+08,  -1.04506908e+13,   0.00000000e+00])
#  message: 'Inequality constraints incompatible'
#     nfev: 117
#      nit: 16
#     njev: 16
#   status: 4
#  success: False
#        x: array([-0.01770669,  0.00124124])
# ::: Iteration 7500 (2500 to go)
# ::: Minimization Failed in finding Confidence Interval!!!!!!
#      fun: 724945228.7293601
#      jac: array([ -2.91877440e+07,  -3.92412883e+11,   0.00000000e+00])
#  message: 'Inequality constraints incompatible'
#     nfev: 106
#      nit: 13
#     njev: 13
#   status: 4
#  success: False
#        x: array([-0.01220945,  0.00369521])
# ::: Iteration 7600 (2400 to go)
# ::: Minimization Failed in finding Confidence Interval!!!!!!
#      fun: 33335528205.467396
#      jac: array([  3.52281088e+08,  -1.20395053e+14,   0.00000000e+00])
#  message: 'Inequality constraints incompatible'
#     nfev: 121
#      nit: 16
#     njev: 16
#   status: 4
#  success: False
#        x: array([ 0.00553304,  0.00055375])
# ::: Iteration 7700 (2300 to go)
# ::: Iteration 7800 (2200 to go)
# ::: Minimization Failed in finding Confidence Interval!!!!!!
#      fun: 1009138454.2609882
#      jac: array([ -4.10946000e+07,  -6.50113361e+11,   0.00000000e+00])
#  message: 'Inequality constraints incompatible'
#     nfev: 107
#      nit: 13
#     njev: 13
#   status: 4
#  success: False
#        x: array([-0.01754932,  0.00310475])
# ::: Iteration 7900 (2100 to go)
# ::: Minimization Failed in finding Confidence Interval!!!!!!
#      fun: 782750632310.93567
#      jac: array([ -1.10784348e+10,  -1.38976675e+16,   0.00000000e+00])
#  message: 'Inequality constraints incompatible'
#     nfev: 107
#      nit: 13
#     njev: 13
#   status: 4
#  success: False
#        x: array([ 0.00121389,  0.00011262])
# ::: Iteration 8000 (2000 to go)
# ::: Iteration 8100 (1900 to go)
# ::: Iteration 8200 (1800 to go)
# ::: Minimization Failed in finding Confidence Interval!!!!!!
#      fun: 1675479438.3196676
#      jac: array([  3.35755520e+07,  -1.37479288e+12,   0.00000000e+00])
#  message: 'Inequality constraints incompatible'
#     nfev: 107
#      nit: 13
#     njev: 13
#   status: 4
#  success: False
#        x: array([ 0.01827043,  0.00243754])
# ::: Iteration 8300 (1700 to go)
# ::: Minimization Failed in finding Confidence Interval!!!!!!
#      fun: 5915805598.2969065
#      jac: array([ -2.35335040e+08,  -9.05113578e+12,   0.00000000e+00])
#  message: 'Inequality constraints incompatible'
#     nfev: 106
#      nit: 13
#     njev: 13
#   status: 4
#  success: False
#        x: array([-0.0054913,  0.0013072])
# ::: Iteration 8400 (1600 to go)
# ::: Iteration 8500 (1500 to go)
# ::: Iteration 8600 (1400 to go)
# ::: Iteration 8700 (1300 to go)
# ::: Iteration 8800 (1200 to go)
# ::: Iteration 8900 (1100 to go)
# ::: Minimization Failed in finding Confidence Interval!!!!!!
#      fun: 61443684215.622765
#      jac: array([  2.44870246e+09,   3.03511593e+14,   0.00000000e+00])
#  message: 'Inequality constraints incompatible'
#     nfev: 134
#      nit: 18
#     njev: 18
#   status: 4
#  success: False
#        x: array([ 0.01435807, -0.00040491])
# ::: Iteration 9000 (1000 to go)
# ::: Iteration 9100 (900 to go)
# ::: Iteration 9200 (800 to go)
# ::: Iteration 9300 (700 to go)
# ::: Iteration 9400 (600 to go)
# ::: Minimization Failed in finding Confidence Interval!!!!!!
#      fun: 16163588242.889772
#      jac: array([  3.64964608e+08,  -4.10053300e+13,   0.00000000e+00])
#  message: 'Inequality constraints incompatible'
#     nfev: 101
#      nit: 13
#     njev: 13
#   status: 4
#  success: False
#        x: array([ 0.0198177 ,  0.00078835])
# ::: Iteration 9500 (500 to go)
# ::: Iteration 9600 (400 to go)
# ::: Iteration 9700 (300 to go)
# ::: Minimization Failed in finding Confidence Interval!!!!!!
#      fun: 8889399738.9671402
#      jac: array([  3.58674048e+08,  -1.69121422e+13,   0.00000000e+00])
#  message: 'Inequality constraints incompatible'
#     nfev: 107
#      nit: 13
#     njev: 13
#   status: 4
#  success: False
#        x: array([ 0.02310408,  0.00105124])
# ::: Iteration 9800 (200 to go)
# ::: Minimization Failed in finding Confidence Interval!!!!!!
#      fun: 1797374707.6611276
#      jac: array([ -1.62079584e+08,  -1.52383090e+12,   0.00000000e+00])
#  message: 'Inequality constraints incompatible'
#     nfev: 107
#      nit: 13
#     njev: 13
#   status: 4
#  success: False
#        x: array([-0.03321712,  0.00235912])
# ::: Minimization Failed in finding Confidence Interval!!!!!!
#      fun: 5364005646.9291239
#      jac: array([  4.21972992e+08,   7.88210418e+12,   0.00000000e+00])
#  message: 'Inequality constraints incompatible'
#     nfev: 123
#      nit: 18
#     njev: 18
#   status: 4
#  success: False
#        x: array([ 0.04229354, -0.00136111])
# ::: Iteration 9900 (100 to go)
# ::: Minimization Failed in finding Confidence Interval!!!!!!
#      fun: 3444008781.6372085
#      jac: array([  6.90752320e+07,  -4.05012837e+12,   0.00000000e+00])
#  message: 'Inequality constraints incompatible'
#     nfev: 119
#      nit: 16
#     njev: 16
#   status: 4
#  success: False
#        x: array([ 0.00124124,  0.00170072])
# ::: Time to run 10000 iterations: 1177.29826593
# ::: Time to create result dict: 0.0447821617126
# ::: Time to create result data frame: 0.021525144577

# %%
_ = plt.hist(model_fatory.data_frame_result['poi_mle'], 50)

# %%
df['true_mu_in_c_0'] = df.apply(lambda x : 1 if x['true_mu']<x['ci_poi_max'][0] and x['true_mu']>x['ci_poi_min'][0] else 0, axis=1)
df['true_mu_in_c_1'] = df.apply(lambda x : 1 if x['true_mu']<x['ci_poi_max'][1] and x['true_mu']>x['ci_poi_min'][1] else 0, axis=1)

# %%
print float(df.true_mu_in_c_1.sum())/len(df)
print float(df.true_mu_in_c_0.sum())/len(df)
# Out:
# 0.6768
# 0.9448

# %%
float(1e-12)
# Out:
# 1e-12

# %%
abs(-2)
# Out:
# 2

# %%
1./np.sqrt(10000)
# Out:
# 0.01
