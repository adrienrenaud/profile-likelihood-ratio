# %%
## not needed but allows to reload new version of Profile_likelihood_ratio.py at import
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
from scipy.optimize import minimize as sp_minimize
# %matplotlib inline

# %%
from Profile_likelihood_ratio import Profile_likelihood_ratio
from Profile_likelihood_ratio import Profile_likelihood_ratio_result

# %%
mu = 0.
sigma = 1.
n_data = 1000
np.random.seed(10)
data = np.random.normal(mu, sigma, n_data)

# %%
plr = Profile_likelihood_ratio(data=data,
                               model='m2_log_likelihood_gaus', 
                               debug_level=0
                              )

# %%
plr.profile_likelihood_ratio_confidence_interval(poi_cl=[0.954499736104, 0.682689492137])
plr.compute_common_stat_on_data()
plr.profile_likelihood_ratio_curve()
res = plr.plr_res

# %%
res.plot_profile_likehood_curve_and_confidence_interval()
